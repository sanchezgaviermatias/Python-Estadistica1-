# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## EJERCICIO 1

# %% [markdown]
# **5 amigos se juntan a comer una pizza de 15 porciones.**
#
# #### a)
# Calcule e imprima cuantas porciones debe comer cada una para que su distribución sea igualitaria.
#
# Defina las variables amigos y porciones como variables

# %%
## Ayuda:
amigos = 5

# %% [markdown]
# #### b)
# Imprima el resultado de manera que le quede así:

# %%
# Out:
# La cantidad de porciones que comerá cada uno es 3

# %% [markdown]
# ####  c)
# Ahora asuma que la pizza tiene 17 porciones, ¿Qué cantidad le tocaría a cada uno? Imprima este resultado
#
# ¿Cuál es la diferencia con respecto al resultado del ejercicio a? _Use la funcion **type()** para distinguir esta diferencia_

# %% [markdown]
# ## EJERCICIO 2

# %% [markdown]
# **Julieta y Javier realizan una apuesta acerca del tamano del area de la cancha de futbol de su colegio. Javier asegura que el area es de 360 metros cuadrados. Julieta, por su lado, afirma que es de 400, sabiendo que el ancho del area es de 10 metros y el largo de 40, escriba una sentencia que defina al ganador**
#
# Tene en cuenta las tres situaciones posibles)

# %%
##Ayuda:
ancho = 10
largo = 40

# %% [markdown]
# _El resultado debe parecerse al siguiente:_

# %%
# Out:
# Gano Julieta

# %% [markdown]
# ## EJERCICIO 3

# %% [markdown]
# **Se afirma que por debajo de los 10 grados, la temperatura se considera fria. Entre los 10 y los 23 se asume que es templado. Si supera los 23 grados, hace calor.**
#
# Utiliza la temperatura actual para definir una variable que se llame "tiempo_hoy", y arma un condicional que defina si hace frio, calor, o esta templado.

# %% [markdown]
# ## EJERCICIO 4

# %% [markdown]
# **Ahora, arma un condicional que devuelva un True si hace calor, y un False en caso contrario**
